# %%
import numpy as np
import setup_plot
from import_data import import_data
import matplotlib.pyplot as plt

run1 = import_data('1.csv')
run2 = import_data('2.csv')
run3 = import_data('3.csv')

plt.plot(run1['temperature'], run1['var_mag'])
plt.plot(run2['temperature'], run2['var_mag'])
plt.plot(run3['temperature'], run3['var_mag'])
