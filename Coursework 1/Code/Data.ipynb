# %% [markdown]
# # Data Analysis for DLA

# %% [markdown]
# ## Section 1
# This method to evaluate the fractal dimension uses the fact that
#
# $N = \frac{R}{a}^d$
#
# so $\ln(N)=d\ln(R/a)+c$ hence the gradient of $\ln(N)$ against $\ln(R)$ is the fractal dimension $d$.

# %%
import numpy as np

file = "output/dla.csv"

number_of_particles, radius = np.loadtxt(file, unpack=True, delimiter=",")

# %%
import matplotlib.pyplot as plt

plt.scatter(np.log(radius), np.log(number_of_particles))
plt.xlabel("radius")
plt.ylabel("number of particles")
[m, c], cov = np.polyfit(np.log(radius), np.log(number_of_particles), 1, cov=True)

x = np.linspace(min(np.log(radius)), max(np.log(radius)), 10)
y = m*x + c
plt.plot(x, y, color="red")

print(f"fractal dimension: {m:.4f} ± {cov[1,1]:.4f}")
# Out:
# fractal dimension: 1.8709 ± 0.0006

# %% [markdown]
# ## Section 2
# The fractal dimension here is calculated using box counting

# %%
from boxcount import *
from glob import glob

# glob("output/output.csv.*")

x = []; y = [];

for i in range(1, 1000, 10):
    x.append(i)
    y.append(calculate_fractal_dimension(f"output/output.csv.{i}", 10, 100, 5))
    print(y)

plt.scatter(x, y)
# Out:
# [7.391298302165664e-17]
# [7.391298302165664e-17, 7.391298302165664e-17]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16, 0.12849641097380993]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16, 0.12849641097380993, 0.22816597060767316]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16, 0.12849641097380993, 0.22816597060767316, 0.39164202049287045]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16, 0.12849641097380993, 0.22816597060767316, 0.39164202049287045, 0.39164202049287045]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16, 0.12849641097380993, 0.22816597060767316, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16, 0.12849641097380993, 0.22816597060767316, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16, 0.12849641097380993, 0.22816597060767316, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.43884911618849903]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16, 0.12849641097380993, 0.22816597060767316, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.43884911618849903, 0.43884911618849903]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16, 0.12849641097380993, 0.22816597060767316, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.43884911618849903, 0.43884911618849903, 0.4974345688737551]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16, 0.12849641097380993, 0.22816597060767316, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.43884911618849903, 0.43884911618849903, 0.4974345688737551, 0.4974345688737551]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16, 0.12849641097380993, 0.22816597060767316, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.43884911618849903, 0.43884911618849903, 0.4974345688737551, 0.4974345688737551, 0.4974345688737551]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16, 0.12849641097380993, 0.22816597060767316, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.43884911618849903, 0.43884911618849903, 0.4974345688737551, 0.4974345688737551, 0.4974345688737551, 0.4974345688737551]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16, 0.12849641097380993, 0.22816597060767316, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.43884911618849903, 0.43884911618849903, 0.4974345688737551, 0.4974345688737551, 0.4974345688737551, 0.4974345688737551, 0.4974345688737551]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16, 0.12849641097380993, 0.22816597060767316, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.43884911618849903, 0.43884911618849903, 0.4974345688737551, 0.4974345688737551, 0.4974345688737551, 0.4974345688737551, 0.4974345688737551, 0.5481019151659478]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16, 0.12849641097380993, 0.22816597060767316, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.43884911618849903, 0.43884911618849903, 0.4974345688737551, 0.4974345688737551, 0.4974345688737551, 0.4974345688737551, 0.4974345688737551, 0.5481019151659478, 0.5481019151659478]
# [7.391298302165664e-17, 7.391298302165664e-17, 2.0031891929302369e-16, 2.0031891929302369e-16, 0.12849641097380993, 0.22816597060767316, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.39164202049287045, 0.43884911618849903, 0.43884911618849903, 0.4974345688737551, 0.4974345688737551, 0.4974345688737551, 0.4974345688737551, 0.4974345688737551, 0.5481019151659478, 0.5481019151659478, 0.5481019151659478]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-5ce25e54b0bf> in <module>
#       8 for i in range(1, 1000, 10):
#       9     x.append(i)
# ---> 10     y.append(calculate_fractal_dimension(f"output/output.csv.{i}", 10, 100, 5))
#      11     print(y)
#      12
#
# ~/OneDrive - University of Bath/Physics/Year 3/Semester 2/Comp B/Labs/Coursework 1/Code/boxcount.py in calculate_fractal_dimension(datafile, start, stop, step, visual_output)
#      51     for n in range(start, stop, step):
#      52         data[0].append(1 / n)
# ---> 53         data[1].append(boxcount(datafile, n))
#      54
#      55     [m, c] = np.polyfit(np.log(data[0]), np.log(data[1]), 1)
#
# ~/OneDrive - University of Bath/Physics/Year 3/Semester 2/Comp B/Labs/Coursework 1/Code/boxcount.py in boxcount(datafile, N, visual_output)
#       4 def boxcount(datafile, N, visual_output=False):
#       5     # Load CSV Data
# ----> 6     data = np.loadtxt(datafile, delimiter=',', unpack=True, usecols=[0, 1, 3], skiprows=1)
#       7
#       8     # Filter only cluster points
#
# /usr/local/lib/python3.9/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1139         for x in read_data(_loadtxt_chunksize):
#    1140             if X is None:
# -> 1141                 X = np.array(x, dtype)
#    1142             else:
#    1143                 nshape = list(X.shape)
#
# KeyboardInterrupt:
