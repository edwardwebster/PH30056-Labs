# %% [markdown]
# # DLA Density Analysis

# %%
from boxcount import *

# %%
p=0.1
d=fractal_dimension("Density/output.0001.csv", 2, 30, 10, True, False)
print(f"p={p}%:\t {d[0]:.3f} ± {d[1]:.3f}")
# Out:
# p=0.1%:	 1.690 ± 0.020

# %%
p=0.5
d=fractal_dimension("Density/output.0005.csv", 2, 60, 5, True, False)
print(f"p={p}%:\t {d[0]:.3f} ± {d[1]:.3f}")
# Out:
# p=0.5%:	 1.708 ± 0.010

# %%
p=1
d=fractal_dimension("Density/output.001.csv", 2, 25, 1, True, False)
print(f"p={p}%:\t {d[0]:.3f} ± {d[1]:.3f}")
# Out:
# p=1%:	 1.706 ± 0.006

# %%
p=5
d=fractal_dimension("Density/output.005.csv", 2, 20, 1, True, False)
print(f"p={p}%:\t {d[0]:.3f} ± {d[1]:.3f}")
# Out:
# p=5%:	 1.735 ± 0.009

# %%
p=10
d=fractal_dimension("Density/output.010.csv", 20, 60, 1, True, False)
print(f"p={p}%:\t {d[0]:.3f} ± {d[1]:.3f}")
# Out:
# p=10%:	 1.799 ± 0.006

# %%
p=25
d=fractal_dimension("Density/output.025.csv", 30, 80, 1, True, False)
print(f"p={p}%:\t {d[0]:.3f} ± {d[1]:.3f}")
# Out:
# p=25%:	 1.935 ± 0.001

# %%
p=50
d=fractal_dimension("Density/output.050.csv", 80, 140, 5, True, False)
print(f"p={p}%:\t {d[0]:.3f} ± {d[1]:.3f}")
# Out:
# p=50%:	 1.957 ± 0.003

# %%
import density
import matplotlib.pyplot as plt

figure_folder = "../Report/Figures/"

fsize = 15
tsize = 18

tdir = 'in'

major = 5.0
minor = 3.0

style = 'default'

plt.style.use(style)
# plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] =  'serif'
plt.rcParams['font.size'] = fsize
plt.rcParams['legend.fontsize'] = tsize
plt.rcParams['xtick.direction'] = tdir
plt.rcParams['ytick.direction'] = tdir
plt.rcParams['xtick.major.size'] = major
plt.rcParams['xtick.minor.size'] = minor
plt.rcParams['ytick.major.size'] = major
plt.rcParams['ytick.minor.size'] = minor

# %%
from scipy.signal import savgol_filter
import numpy as np

fig = plt.figure(figsize=[10, 6])

plt.errorbar(density.size, density.dimension, density.error, fmt='o', color='black', capsize=5, label='Fractal Dimension')
plt.xlabel("Cluster Size")
plt.ylabel("Fractal Dimension")
plt.title("Fractal dimension of a growing cluster")

x = np.arange(min(density.size),max(density.size), 10)
y = 1.6e-8*x*x+1.7
plt.plot(x, y, 'r-', label="Trend")
plt.legend()

plt.plot([500, 500], [1.55, 1.95], '--', color='black')
plt.ylim(1.55, 1.95)

plt.show()

# %%
fig.savefig(figure_folder + "5.png", dpi=300, transparent=True, padding=0)
# Out:
# <ipython-input-16-9bbcad6bce1e>:1: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "padding" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.savefig(figure_folder + "5.png", dpi=300, transparent=True, padding=0)
